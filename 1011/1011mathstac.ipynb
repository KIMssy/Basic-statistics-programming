# %%
# !python  --version
# Out:
# Python 3.7.14

# %%
# !wget https://www.python.org/ftp/python/3.9.9/Python-3.9.9.tgz
# !tar xvfz Python-3.9.9.tgz
# !Python-3.9.9/configure
# !make
# !sudo make install

# %%
# !python  --version
# Out:
# Python 3.9.9

# %%
import math

# %%
def permutations_count(n, r):
  return math.factorial(n) //math.factorial(n-1)

print(permutations_count(4, 2))
# Out:
# 4

# %%
def combination_count(n,r):
  return math.factorial(n) //math.factorial(n - r)* math.factorial(r)

print(combination_count(4, 2))
# Out:
# 24

# %%
def permutation_with_repetition_count(n, r):
  return math.pow(n,r)

print(permutation_with_repetition_count(4, 2))
# Out:
# 16.0

# %%
def permutation_with_repetition_count2(n, r):
  a = n+r -1
  b = r
  return math.factorial(a) //(math.factorial(a-b)*math.factorial(b))

print(permutation_with_repetition_count2(4, 2))
# Out:
# 10

# %% [markdown]
# pow 함수, 프린트 5번은 순열

# %%
from itertools import permutations

# %%
arr = [1,2,3]
print(list(permutations(arr,2)))
# Out:
# [(1, 2), (1, 3), (2, 1), (2, 3), (3, 1), (3, 2)]

# %%
def gen_permutations(arr, n):
  result = []

  if n == 0:
    return [[]]
  
  for i, eiem in enumerate(arr):
    for P in gen_permutations(arr[:i] + arr[i+1:], n-1):
      print(i,P)
      result += ([elem]+P)

  return result

# %%
for i, letter in enumerate(['A','B','C'], start = 1):
  print(i, letter)
# Out:
# 1 A
# 2 B
# 3 C

# %%
arr = [1,2,3]
print(gen_permutations(arr,2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-a8b980eee75e> in <module>
#       1 arr = [1,2,3]
# ----> 2 print(gen_permutations[arr,2])
#
# TypeError: 'function' object is not subscriptable

# %%
def gen_permutation(arr, n):
  result = []

  if n == 0:
    return [[]]
  
  for i, eiem in enumerate(arr):
    for P in gen_permutations(arr[:i] + arr[i+1:], n-1):
      print(i,P)
      result += [[elem]+P]

  return result

# %%
for i, letter in enumerate(['A','B','C'], start = 1):
  print(i, letter)
# Out:
# 1 A
# 2 B
# 3 C

# %% [markdown]
# 배열을 통한 프로그래밍

# %%
arr = [1, 2, 3]

print(list(permutations(arr,2)))
# Out:
# [(1, 2), (1, 3), (2, 1), (2, 3), (3, 1), (3, 2)]

# %%
def gen_permutation(arr, n):
  result = []

  if n == 0:
    return [[]]
  
  for i, eiem in enumerate(arr):

    for P in gen_permutations(arr[:i] + arr[i+1:], n-1):
      print(i,P)
      print(P)
      result += [[elem]+P]

  return result

# %%
  arr = [3,4,5]
  
  def gen_permutation(arr, n):
    result = []

    if n == 0:
      return [[]]
    for i, elem in enumerate(arr):
      print(i,elem)
      for P in gen_permutations(arr[:1] +arr[i+1:], n-1):
        print(P)

arr = [3,4,5]

# %% [markdown]
# enumerate()함수

# %%
for i, letter in enumerate(['A', 'B', 'C'], start=1):
  print(i, letter)
# Out:
# 1 A
# 2 B
# 3 C

# %%
arr = [0,1,2,3,4,5]
print(gen_permutation(arr,2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-f8e7341544c8> in <module>
#       1 arr = [0,1,2,3,4,5]
# ----> 2 print(gen_permutation(arr,2))
#
# <ipython-input-22-c85136e4570d> in gen_permutation(arr, n)
#       6
#       7   for i, eiem in enumerate(arr):
# ----> 8     for P in gen_permutations(arr[:i] + arr[i+1:], n-1):
#       9       result += [[elem]+P]
#      10
#
# NameError: name 'gen_permutations' is not defined

# %% [markdown]
# 재귀함수

# %%
def hello (count):
  if count ==0: #종료,조건을 만듦 카운트가 0이면 다시 헬로함수를 호출하지않고 끝냄
     return

  print('Hello. World!', count)
  
  count -= 1    #카운트를 감소시킨뒤
  hello(count)   #다시헬로에 넣음

hello(5)   #헬로함수 호출
# Out:
# Hello. World! 5
# Hello. World! 4
# Hello. World! 3
# Hello. World! 2
# Hello. World! 1

# %% [markdown]
# 시험 암기

# %% [markdown]
# ambmcmd
