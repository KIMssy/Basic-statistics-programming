# %% [markdown]
# 8-5) 0에서 3까지 숫자가 각각 하나씩 적힌 4장의 카드가 있습니다. 이 중 3장을 택하여 만들 수 있는 세 자리 수 중 홀수의 개수를 구하세요.

# %%
def gen_permutations(arr, n):
  result = []

  if n == 0:
    return [[]]
  
  for i, eiem in enumerate(arr):
      for P in gen_permutations(arr[:i] + arr[i+1:], n-1):
        result += [[elem]+P]

  return result

# %%
arr = [0,1,2,3]

result = gen_permutations(arr,3)
print(result)

for i in result:
  print(i)
  b= i[0]*100+i[1]*10+i[2]
  print(i," : ",b)
  if (b%2) == 1:  #b를 나눈 나머지가 홀수인 경
    print('odd number =', b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ba0a80c5e051> in <module>
#       1 arr = [0,1,2,3]
#       2
# ----> 3 result = gen_permutations(arr,3)
#       4 print(result)
#       5
#
# <ipython-input-7-bb3fed8d2ebc> in gen_permutations(arr, n)
#       6
#       7   for i, eiem in enumerate(arr):
# ----> 8       for P in gen_permutations(arr[:i] + arr[i+1:], n-1):
#       9         result += [[elem]+P]
#      10
#
# <ipython-input-7-bb3fed8d2ebc> in gen_permutations(arr, n)
#       6
#       7   for i, eiem in enumerate(arr):
# ----> 8       for P in gen_permutations(arr[:i] + arr[i+1:], n-1):
#       9         result += [[elem]+P]
#      10
#
# <ipython-input-7-bb3fed8d2ebc> in gen_permutations(arr, n)
#       7   for i, eiem in enumerate(arr):
#       8       for P in gen_permutations(arr[:i] + arr[i+1:], n-1):
# ----> 9         result += [[elem]+P]
#      10
#      11   return result
#
# NameError: name 'elem' is not defined

# %%
from itertools import combinations

# %%
arr = [0,1,2,3,4,5]

print(list(combinations(arr,3)))
# Out:
# [(0, 1, 2), (0, 1, 3), (0, 1, 4), (0, 1, 5), (0, 2, 3), (0, 2, 4), (0, 2, 5), (0, 3, 4), (0, 3, 5), (0, 4, 5), (1, 2, 3), (1, 2, 4), (1, 2, 5), (1, 3, 4), (1, 3, 5), (1, 4, 5), (2, 3, 4), (2, 3, 5), (2, 4, 5), (3, 4, 5)]

# %%
#재귀함수 이용

# %%
def gen_combinations(arr,n):
  result = []

  if n == 0:
    return [[]]

  for i in range(0, len(arr)):
    elem = arr[i]
    rest_arr = arr[i+1:]
    for C in gen_combinations(rest_arr, n-1):
      result.append([elem+C])

  return result

# %%
arr = [0,1,2,3]

print(gen_combinations(arr,2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-40be5a6c29f0> in <module>
#       1 arr = [0,1,2,3]
#       2
# ----> 3 print(gen_combinations(arr,2))
#
# <ipython-input-14-b5870aa5e588> in gen_combinations(arr, n)
#       8     elem = arr[i]
#       9     rest_arr = arr[i+1:]
# ---> 10     for C in gen_combinations(rest_arr, n-1):
#      11       result.append([elem+C])
#      12
#
# <ipython-input-14-b5870aa5e588> in gen_combinations(arr, n)
#       9     rest_arr = arr[i+1:]
#      10     for C in gen_combinations(rest_arr, n-1):
# ---> 11       result.append([elem+C])
#      12
#      13   return result
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
def choose(n,k):
  if k == 0:
    return [[]]

  for i in
