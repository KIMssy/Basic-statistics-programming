# %% [markdown]
# 네 개의 문자를 일렬로 나열하는 경우의 수

# %%
import

# %%
def gen_permutation(arr, n):
  result = []

  if n == 0:
    return [[]]
  
  for i, eiem in enumerate(arr):

    for P in gen_permutations(arr[:i] + arr[i+1:], n-1):
      print(i,P)
      print(P)
      result += [[elem]+P]

  return result

# %%
array = [''a', b', 'c','d']
print(gen_permutations(array,4))
print(len((gen_permutations(array,4)))
